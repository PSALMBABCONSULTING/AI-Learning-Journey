# %% [markdown]
# # Lesson 03: Operators and Expressions in Python
#
# In this lesson, we will learn how Python performs calculations, comparisons, assignments, and logical checks.
#
# Operators are useful in healthcare analytics because they help calculate metrics, compare performance against targets, and create decision logic for reports and dashboards.

# %% [markdown]
# ## Lesson Goals
#
# By the end of this lesson, you should be able to:
#
# - Use arithmetic operators
# - Use comparison operators
# - Use assignment operators
# - Use logical operators
# - Apply operators to generic healthcare analytics examples

# %% [markdown]
# ## 1. What Are Operators?
#
# Operators are symbols or keywords that Python uses to perform calculations, compare values, assign values, or combine conditions.

# %% [markdown]
# ## 2. Arithmetic Operators
#
# Arithmetic operators are used for calculations.
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `+` | Addition | `total_patients + new_admissions` |
# | `-` | Subtraction | `total_patients - discharged_patients` |
# | `*` | Multiplication | `fall_rate * 100` |
# | `/` | Division | `fall_incidents / total_patients` |
# | `%` | Remainder | `10 % 3` |
# | `**` | Power | `2 ** 3` |

# %%
total_patients = 150
fall_incidents = 12

fall_rate = (fall_incidents / total_patients) * 100

print("Fall Rate:", fall_rate)

# %% [markdown]
# ## 3. Rounding Numbers
#
# Use `round()` to make decimal outputs easier to read.

# %%
print("Fall Rate (%):", round(fall_rate, 2))

# %% [markdown]
# ## 4. More Arithmetic Examples
#
# Now we will calculate remaining patients and readmission rate.

# %%
discharged_patients = 135
readmission_count = 8

remaining_patients = total_patients - discharged_patients
readmission_rate = (readmission_count / discharged_patients) * 100

print("Remaining Patients:", remaining_patients)
print("Readmission Rate (%):", round(readmission_rate, 2))

# %% [markdown]
# ## 5. Comparison Operators
#
# Comparison operators compare values and return either `True` or `False`.
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `==` | Equal to | `compliance_rate == 90` |
# | `!=` | Not equal to | `care_area != "Emergency"` |
# | `>` | Greater than | `fall_rate > 5` |
# | `<` | Less than | `compliance_rate < 90` |
# | `>=` | Greater than or equal to | `compliance_rate >= 90` |
# | `<=` | Less than or equal to | `bed_occupancy_rate <= 95` |

# %%
compliance_rate = 88.5
bed_occupancy_rate = 94.2

print("Fall rate above 5%:", fall_rate > 5)
print("Compliance meets 90% target:", compliance_rate >= 90)
print("Bed occupancy below or equal to 95%:", bed_occupancy_rate <= 95)

# %% [markdown]
# ## 6. Assignment Operators
#
# Assignment operators are used to assign or update values.
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `=` | Assign value | `fall_incidents = 12` |
# | `+=` | Add and update | `fall_incidents += 1` |
# | `-=` | Subtract and update | `total_patients -= 5` |
# | `*=` | Multiply and update | `score *= 2` |
# | `/=` | Divide and update | `rate /= 100` |

# %%
fall_incidents = 12
total_patients = 150

fall_incidents += 1
total_patients -= 2

print("Updated Fall Incidents:", fall_incidents)
print("Updated Total Patients:", total_patients)

# %% [markdown]
# ## 7. Logical Operators
#
# Logical operators combine conditions.
#
# | Operator | Meaning | Example |
# |---|---|---|
# | `and` | Both conditions must be true | `fall_rate > 5 and compliance_rate < 90` |
# | `or` | At least one condition must be true | `fall_rate > 5 or compliance_rate < 90` |
# | `not` | Reverses the result | `not training_completed` |

# %%
fall_rate = 8.0
compliance_rate = 88.5
bed_occupancy_rate = 94.2
remaining_patients = 15
training_completed = False

needs_quality_review = fall_rate > 5 and compliance_rate < 90
needs_capacity_review = bed_occupancy_rate > 95 or remaining_patients < 10
training_follow_up_required = not training_completed

print("Needs Quality Review:", needs_quality_review)
print("Needs Capacity Review:", needs_capacity_review)
print("Training Follow-up Required:", training_follow_up_required)

# %% [markdown]
# ## 8. Practice Task
#
# Add two extra variables:
#
# ```python
# infection_count = 5
# medication_error_count = 3
# ```
#
# Then calculate:
#
# ```python
# infection_rate = (infection_count / total_patients) * 100
# medication_error_rate = (medication_error_count / total_patients) * 100
# ```
#
# Finally, print both rates.

# %%
infection_count = 5
medication_error_count = 3

infection_rate = (infection_count / total_patients) * 100
medication_error_rate = (medication_error_count / total_patients) * 100

print("Infection Rate (%):", round(infection_rate, 2))
print("Medication Error Rate (%):", round(medication_error_rate, 2))

# %% [markdown]
# ## Full Practice Code
#
# The full Python practice code for this lesson is available in the practice folder:
#
# [View Lesson 03 Practice Code](../practice/lesson_03_operators.py)
#
# This file contains the complete Python script for arithmetic, comparison, assignment, and logical operators.

# %% [markdown]
# ## Check Your Understanding
#
# Answer this in your own words:
#
# **Why are operators useful in healthcare analytics?**

# %% [markdown]
# ## My Career Application
#
# Understanding operators is important because healthcare analytics often involves calculations, comparisons, and decision logic. These same concepts are used in SQL, Power BI, Python, machine learning, and AI workflows.
