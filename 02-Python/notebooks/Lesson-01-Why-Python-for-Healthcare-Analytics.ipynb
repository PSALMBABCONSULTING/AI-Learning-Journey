# %% [markdown]
# # Lesson 01: Why Python Matters for Healthcare Analytics and AI
#
# In this lesson, we will learn why Python is useful for healthcare analytics, automation, machine learning, and artificial intelligence.
#
# Python is one of the most important tools for moving from basic reporting into advanced analytics and AI-enabled decision support.

# %% [markdown]
# ## Lesson Goals
#
# By the end of this lesson, you should be able to explain:
#
# - Why Python is useful in healthcare analytics
# - How Python supports automation
# - How Python supports data cleaning
# - How Python connects to machine learning and AI
# - How Python can support your growth as a healthcare analytics leader

# %% [markdown]
# ## 1. Why Python?
#
# Python is a programming language used for:
#
# - Data analysis
# - Automation
# - Machine learning
# - Artificial intelligence
# - Data cleaning
# - Visualization
# - Reporting workflows
#
# In healthcare analytics, Python can help turn raw data into useful insights.

# %% [markdown]
# ## 2. Healthcare Analytics Use Cases
#
# Python can help with tasks such as:
#
# - Combining monthly healthcare data files
# - Cleaning messy Excel or CSV data
# - Creating calculated fields
# - Summarizing quality indicators
# - Preparing data for dashboards
# - Building machine learning models
# - Supporting AI workflows

# %% [markdown]
# ## 3. Simple Python Example
#
# This first example prints a message about Python and healthcare analytics.

# %%
print("Python is useful for healthcare analytics and AI.")

# %% [markdown]
# ## 4. Storing a Healthcare Analytics Message
#
# We can store a message in a variable and print it.

# %%
learning_goal = "Use Python to support healthcare analytics, automation, and AI."

print(learning_goal)

# %% [markdown]
# ## 5. Generic Healthcare Example
#
# Suppose we want to describe a simple healthcare reporting workflow.

# %%
raw_data_source = "Monthly healthcare quality data"
process_step = "Clean and summarize data using Python"
reporting_output = "Dashboard-ready dataset"

print("Raw Data Source:", raw_data_source)
print("Process Step:", process_step)
print("Reporting Output:", reporting_output)

# %% [markdown]
# ## 6. Career Connection
#
# Python matters because it helps an analyst move beyond manual reporting into automation, reproducible analysis, machine learning, and AI-enabled healthcare analytics.
#
# For a healthcare analytics leader, Python is not just about writing code. It is about understanding how data workflows can become more reliable, scalable, and useful for decision-making.

# %% [markdown]
# ## Full Practice Code
#
# The complete practice script for this lesson can be placed here:
#
# [View Lesson 01 Practice Code](../practice/lesson_01_why_python.py)
#
# If you do not have this file yet, you can create it later. The notebook itself can be used for step-by-step teaching.

# %% [markdown]
# ## Check Your Understanding
#
# Answer this in your own words:
#
# **Why is Python useful for healthcare analytics and AI?**
