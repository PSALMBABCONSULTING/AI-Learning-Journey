# %% [markdown]
# # Lesson 02: Variables, Data Types, and Comments
#
# In this lesson, I am learning how to use variables, common data types, comments, and print statements in Python using generic healthcare analytics examples.

# %%
dashboard_name = "Fall Risk Dashboard"

# %%
print(dashboard_name)
# Out:
# Fall Risk Dashboard
